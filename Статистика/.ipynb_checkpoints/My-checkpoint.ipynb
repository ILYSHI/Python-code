# %%
x = 'Hello, Data Science'
x
# Out:
# 'Hello, Data Science'

# %%
print(x)
# Out:
# Hello, Data Science

# %%
2>3
# Out:
# False

# %%
pip install pandas

# %%
pip instal numpy

# %%
import pandas as pd
import numpy as np

# %%
4>5
